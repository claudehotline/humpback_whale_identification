# %%
import os

import pandas as pd
import numpy as np
import cv2
import seaborn as sns
import matplotlib.pyplot as plt
import collections
from PIL import Image
import matplotlib.image as mpimg
import matplotlib.patches as patches
import random

DATA_DIR = "..\\..\\data\\humpback-whale-identification"

# %%
train = pd.read_csv(os.path.join(DATA_DIR, "train.csv"))
test = pd.read_csv(os.path.join(DATA_DIR, "sample_submission.csv"))

train.shape, test.shape
# Out:
# ((25361, 2), (7960, 2))

# %%
os.listdir(DATA_DIR)
# Out:
# ['sample_submission.csv', 'test', 'train', 'train.csv']

# %%
train.head()
# Out:
#            Image         Id
# 0  0000e88ab.jpg  w_f48451c
# 1  0001f9222.jpg  w_c3d896a
# 2  00029d126.jpg  w_20df2c5
# 3  00050a15a.jpg  new_whale
# 4  0005c1ef8.jpg  new_whale

# %%
test.head()
# Out:
#            Image                                                 Id
# 0  00028a005.jpg  new_whale w_23a388d w_9b5109b w_9c506f6 w_0369a5c
# 1  000dcf7d8.jpg  new_whale w_23a388d w_9b5109b w_9c506f6 w_0369a5c
# 2  000e7c7df.jpg  new_whale w_23a388d w_9b5109b w_9c506f6 w_0369a5c
# 3  0019c34f4.jpg  new_whale w_23a388d w_9b5109b w_9c506f6 w_0369a5c
# 4  001a4d292.jpg  new_whale w_23a388d w_9b5109b w_9c506f6 w_0369a5c

# %%
random_train_whales = np.random.choice([os.path.join(DATA_DIR + '/train', whale) for whale in train['Image']], 3)
random_test_whales = np.random.choice([os.path.join(DATA_DIR + '/test', whale) for whale in test['Image']], 3)

both_whales = np.concatenate([random_train_whales, random_test_whales])

print('Training Images:')

for i, whale in enumerate(both_whales):
    if i == 3:
        print('Test Images:')
    img = Image.open(whale)
    plt.imshow(img)
    plt.show()
# Out:
# Training Images:
# Test Images:

# %%
train['Id'].value_counts()[:5]
# Out:
# new_whale    9664
# w_23a388d      73
# w_9b5109b      65
# w_9c506f6      62
# w_0369a5c      61
# Name: Id, dtype: int64

# %%
plt.title('Distribution of Classes excluding new_whale');
train.Id.value_counts()[1:].plot(kind='hist', bins=8,figsize=(20,14));

# %%
fig = plt.figure(figsize = (20, 15))
for idx, img_name in enumerate(train[train['Id'] == 'new_whale']['Image'][:12]):
    y = fig.add_subplot(3, 4, idx+1)
    img = cv2.imread(os.path.join(DATA_DIR, 'train', img_name))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    y.imshow(img)
    
plt.show()
